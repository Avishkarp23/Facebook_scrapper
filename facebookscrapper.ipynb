# %%
from  selenium import webdriver
from  selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

import time
/html/body/div[1]/div/div[1]/div/div[3]/div/div/div/div[1]/div[1]/div[4]/div[2]/div/div[2]/div/div/div/div[2]/div[2]/div/div/div/div/div/div/div/div/div/div[2]/div/div/div[3]/div[1]/div/div/div/span/div[3]/div/div

# %%
n = int(input("Enter the number of posts you want to scrap"))
# Out:
# Enter the number of posts you want to scrap100

# %%
driver= webdriver.Chrome("chromedriver")
driver.get("https://www.facebook.com/login")
email="tier3clgwalla@gmail.com"
password="7894561230@Vi"
time.sleep(5)
driver.find_element(By.ID,"email").send_keys(email)
driver.find_element(By.ID,"pass").send_keys(password)
driver.find_element(By.ID,"loginbutton").click()
time.sleep(10)
driver.get("https://www.facebook.com/FindMyRoomPune")
time.sleep(4)
for i in range(2,n):
    click=1;
    try:
        a=driver.find_element(By.XPATH,"/html/body/div[1]/div/div[1]/div/div[3]/div/div/div/div[1]/div[1]/div[4]/div[2]/div/div[2]/div/div/div/div[2]/div["+str(i)+"]/div/div/div/div/div/div/div/div/div/div[2]/div/div/div[3]/div[1]/div/div/div/span/div[3]/div/div")
    except:
        click=0
        print("Blank Post")
    if click==1:
        a.click()
    time.sleep(2)
# Out:
# Blank Post
# Blank Post
# Blank Post
# Blank Post
# Blank Post
# Blank Post
# Blank Post
# Blank Post
# Blank Post
# Blank Post
# Blank Post
# Blank Post
# Blank Post
# Blank Post
# Blank Post
# Blank Post
# Blank Post
# Blank Post
# Blank Post
# Blank Post
# Blank Post
# Blank Post
# Blank Post
# Blank Post

# %%
/html/body/div[1]/div/div[1]/div/div[3]/div/div/div/div[1]/div[1]/div[4]/div[2]/div/div[2]/div/div/div/div[2]/div[2]/div/div/div/div/div/div/div/div/div/div[2]/div/div/div[3]/div[1]/div/div/div/span/div[3]/div/div
/html/body/div[1]/div/div[1]/div/div[3]/div/div/div/div[1]/div[1]/div[4]/div[2]/div/div[2]/div/div/div/div[2]/div["+str(i)"]/div/div/div/div/div/div/div/div/div/div[2]/div/div/div[3]/div[1]/div/div/div/span/div[3]/div/div

# %%
page_source=driver.page_source
from bs4 import BeautifulSoup as bs
soup=bs(page_source,'html.parser')
desc_list=[]
#print(soup.prettify())
data=soup.find_all('div',attrs={'class':'x9f619 x1n2onr6 x1ja2u2z x2bj2ny x1qpq9i9 xdney7k xu5ydu1 xt3gfkd xh8yej3 x6ikm8r x10wlt62 xquyuld'})
for i in data:
    a= i.find('span',attrs={'class':'x193iq5w xeuugli x13faqbe x1vvkbs x1xmvt09 x1lliihq x1s928wv xhkezso x1gmr53x x1cpjm7i x1fgarty x1943h6x xudqn12 x3x7a5m x6prxxf xvq8zen xo1l8bm xzsf02u x1yc453h'})
    if(a!=None):
        desc_list.append(a)
    
#print(desc_list)
newl=[]
count =0
for i in desc_list:
    count+=1
    print("Post Number"+str(count)+":"+ i.text)
    newl.append(i.text)
    print("")
# Out:
# Post Number1:Now, find a property for rent without the help of a broker!FindMyRoom Pune helps people to rent a p
#
# Post Number2:Looking For A Roommate? Get Your Perfect Roommate on FindMyRoom easily, safely & securely. Find a room. Rent your room. Join thousands: https://findmyroom.in
#
# ...

# %%
import pandas as pd
df=pd.DataFrame({"post description":newl})
df.to_csv("Findroom1.csv")
